# %%
from moonshine_voice import (
    MicTranscriber,
    TranscriptEventListener,
    get_model_for_language,
    ModelArch
)
import argparse
import sys
import time

# %%
sys.argv = [sys.argv[0]]
model_path, model_arch = moonshine_voice.get_model_for_language("en",ModelArch.TINY_STREAMING)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 sys.argv = [sys.argv[0]]
# ----> 2 model_path, model_arch = moonshine_voice.get_model_for_language("en",ModelArch.TINY_STREAMING)
#
# NameError: name 'moonshine_voice' is not defined

# %%
class TerminalListener(TranscriptEventListener):
    def __init__(self):
        self.last_line_text_length = 0

    # Assume we're on a terminal, and so we can use a carriage return to
    # overwrite the last line with the latest text.
    def update_last_terminal_line(self, new_text: str):
        print(f"\r{new_text}", end="", flush=True)
        if len(new_text) < self.last_line_text_length:
            # If the new text is shorter than the last line, we need to
            # overwrite the last line with spaces.
            diff = self.last_line_text_length - len(new_text)
            print(f"{' ' * diff}", end="", flush=True)
        # Update the length of the last line text.
        self.last_line_text_length = len(new_text)

    def on_line_started(self, event):
        self.last_line_text_length = 0

    def on_line_text_changed(self, event):
        self.update_last_terminal_line(event.line.text)

    def on_line_completed(self, event):
        self.update_last_terminal_line(event.line.text)
        print("\n", end="", flush=True)


# If we're not on an interactive terminal, print each line as it's completed.

# %%
class FileListener(TranscriptEventListener):
    def on_line_completed(self, event):
        print(event.line.text)

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Basic transcription example")
    parser.add_argument(
        "--language", type=str, default="en", help="Language to use for transcription"
    )
    parser.add_argument(
        "--model-arch",
        type=int,
        default=2,
        help="Model architecture to use for transcription",
    )
    args = parser.parse_args()
    model_path, model_arch = get_model_for_language(args.language, args.model_arch)

    mic_transcriber = MicTranscriber(model_path=model_path, model_arch=model_arch)

    if sys.stdout.isatty():
        listener = TerminalListener()
    else:
        listener = FileListener()

    print("Listening to the microphone, press Ctrl+C to stop...", file=sys.stderr)
    mic_transcriber.add_listener(listener)
    mic_transcriber.start()
    try:
        while True:
            time.sleep(0.1)
    finally:
        mic_transcriber.stop()
        mic_transcriber.close()
# Out:
# Listening to the microphone, press Ctrl+C to stop...
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# Okay, now we can say something and maybe this one will.
# MicTranscriber: input overflow
# Oh,
# How much?
# MicTranscriber: input overflow
# Whether we try to, if we try to,
# MicTranscriber: input overflow
#
# Thank you.
# So we need to.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# Yeah, because we also had problems with our.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# Accidents that I could reach, you know, injuries, and pain.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# But does it does it correct? correct?
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# This one, I just trying,
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# How is the microtranscript of the words of theirs? there's a refiner.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# She sells, she sells.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# By these words.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# So, please share on this show.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# Some fish are on this floor, with a pump.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# We try to put upwards.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# I'm sure she's fine.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# For March, we were there with our child, and we talked with Chuf.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# Oh, no.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# She does her take at of Cotever,
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# The plunge railway after the police entered.
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# MicTranscriber: input overflow
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 27
#      25 try:
#      26     while True:
# ---> 27         time.sleep(0.1)
#      28 finally:
#      29     mic_transcriber.stop()
#
# KeyboardInterrupt:

# %%
import llama_cpp
